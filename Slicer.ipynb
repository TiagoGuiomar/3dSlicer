# %%
import slicer #Import slicer

#Set viewer size to 50% of screen size
slicernb.AppWindow.setWindowSize(scale=0.5)

#Hide patient information from slice view
slicernb.showSliceViewAnnotations(False)

# %%
import Slicer
Slicer.slicer
Slicer.slicer.MRMLScene.GetNumberOfNodesByClass ('vtkMRMLScalarVolumeNode1')

# %%
import JupyterNotebooksLib as slicernb
slicernb.ViewDisplay()

# %%
slicernb.ViewLightboxDisplay("Red", rangeShrink=[1,5])

# %%
# Slice view display
from ipywidgets import interact
@interact(position=(0,100))
def update(position=50):
    return slicernb.ViewSliceDisplay('Red', positionPercent=position)
